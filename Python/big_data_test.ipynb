# %%
from big_data import test_mlp
test_mlp(batch_size=1000, n_epochs=50, n_hidden=[50,100],
                lr=0.1, L1_reg=1, L2_reg=1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-dae42e8188f3> in <module>()
#       1 from big_data import test_mlp
#       2 test_mlp(batch_size=1000, n_epochs=50, n_hidden=[50,100],
# ----> 3                 lr=0.1, L1_reg=1, L2_reg=1)
#
# /home/ubuntu/big data/src/big_data.pyc in test_mlp(batch_size, n_epochs, n_hidden, lr, L1_reg, L2_reg)
#     695     train_nn(train_model, validate_model, test_model,
#     696         n_train_batches, n_valid_batches, n_test_batches, n_epochs,
# --> 697         verbose = True)
#
# /home/ubuntu/big data/src/big_data.pyc in train_nn(train_model, validate_model, test_model, n_train_batches, n_valid_batches, n_test_batches, n_epochs, verbose)
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=10, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Amazon_Instant_Video_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 42043/42043, validation error 34.598587 %
#      epoch 1, minibatch 42043/42043, test error of best model 34.508477 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# epoch 2, minibatch 42043/42043, validation error 34.598587 %
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# epoch 3, minibatch 42043/42043, validation error 82.832370 %
# training @ iter =  130000
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# epoch 4, minibatch 42043/42043, validation error 34.598587 %
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=50, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Apps_for_Android_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# epoch 1, minibatch 37989/37989, validation error 47.150912 %
#      epoch 1, minibatch 37989/37989, test error of best model 47.068802 %
# training @ iter =  40000
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# epoch 2, minibatch 37989/37989, validation error 47.150912 %
# training @ iter =  80000
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# epoch 3, minibatch 37989/37989, validation error 47.150912 %
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# training @ iter =  150000
# epoch 4, minibatch 37989/37989, validation error 47.150912 %
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# epoch 5, minibatch 37989/37989, validation error 47.150912 %
# training @ iter =  190000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=20, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Automotive_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 49455/49455, validation error 37.848954 %
#      epoch 1, minibatch 49455/49455, test error of best model 37.805926 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# epoch 2, minibatch 49455/49455, validation error 37.848954 %
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# epoch 3, minibatch 49455/49455, validation error 37.848954 %
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# epoch 4, minibatch 49455/49455, validation error 37.848954 %
# training @ iter =  200000
# training @ iter =  210000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=15, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Baby_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 43941/43941, validation error 41.709682 %
#      epoch 1, minibatch 43941/43941, test error of best model 41.525604 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# epoch 2, minibatch 43941/43941, validation error 41.709682 %
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# epoch 3, minibatch 43941/43941, validation error 41.709682 %
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# epoch 4, minibatch 43941/43941, validation error 81.823023 %
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=20, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Beauty_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# epoch 1, minibatch 72830/72830, validation error 38.231587 %
#      epoch 1, minibatch 72830/72830, test error of best model 38.302521 %
# training @ iter =  80000
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# epoch 2, minibatch 72830/72830, validation error 38.231587 %
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# epoch 3, minibatch 72830/72830, validation error 38.231587 %
# training @ iter =  220000
# training @ iter =  230000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=400, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Books_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 40512/40512, validation error 38.345590 %
#      epoch 1, minibatch 40512/40512, test error of best model 38.288879 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# epoch 2, minibatch 40512/40512, validation error 38.345590 %
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# epoch 3, minibatch 40512/40512, validation error 38.345590 %
# training @ iter =  130000
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# epoch 4, minibatch 40512/40512, validation error 38.345590 %
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=50, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_CDs_and_Vinyl_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# training @ iter =  50000
# epoch 1, minibatch 53985/53985, validation error 32.893965 %
#      epoch 1, minibatch 53985/53985, test error of best model 32.814484 %
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# training @ iter =  100000
# epoch 2, minibatch 53985/53985, validation error 32.893965 %
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# epoch 3, minibatch 53985/53985, validation error 82.048016 %
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# epoch 4, minibatch 53985/53985, validation error 32.893965 %
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=50, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Cell_Phones_and_Accessories_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 49640/49640, validation error 81.617044 %
#      epoch 1, minibatch 49640/49640, test error of best model 81.736292 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# epoch 2, minibatch 49640/49640, validation error 50.303536 %
#      epoch 2, minibatch 49640/49640, test error of best model 50.340441 %
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# epoch 3, minibatch 49640/49640, validation error 81.617044 %
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=15, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Digital_Music_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 40128/40128, validation error 25.431434 %
#      epoch 1, minibatch 40128/40128, test error of best model 25.685149 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# epoch 2, minibatch 40128/40128, validation error 25.431434 %
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# epoch 3, minibatch 40128/40128, validation error 25.431434 %
# training @ iter =  130000
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# epoch 4, minibatch 40128/40128, validation error 25.431434 %
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=100, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Electronics_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# training @ iter =  50000
# epoch 1, minibatch 56336/56336, validation error 44.408212 %
#      epoch 1, minibatch 56336/56336, test error of best model 44.397878 %
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# epoch 2, minibatch 56336/56336, validation error 44.408212 %
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# epoch 3, minibatch 56336/56336, validation error 44.408212 %
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# training @ iter =  220000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=20, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Grocery_and_Gourmet_Food_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 46697/46697, validation error 33.802043 %
#      epoch 1, minibatch 46697/46697, test error of best model 33.919127 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# epoch 2, minibatch 46697/46697, validation error 33.802043 %
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# epoch 3, minibatch 46697/46697, validation error 33.802043 %
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# epoch 4, minibatch 46697/46697, validation error 33.802043 %
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=50, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Health_and_Personal_Care_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 42945/42945, validation error 40.230560 %
#      epoch 1, minibatch 42945/42945, test error of best model 40.123397 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# epoch 2, minibatch 42945/42945, validation error 40.230560 %
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# epoch 3, minibatch 42945/42945, validation error 90.005030 %
# training @ iter =  130000
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# epoch 4, minibatch 42945/42945, validation error 40.230560 %
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=50, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Home_and_Kitchen_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# training @ iter =  50000
# training @ iter =  60000
# epoch 1, minibatch 61256/61256, validation error 40.964737 %
#      epoch 1, minibatch 61256/61256, test error of best model 41.093388 %
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# epoch 2, minibatch 61256/61256, validation error 40.964737 %
# training @ iter =  130000
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# epoch 3, minibatch 61256/61256, validation error 40.964737 %
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# training @ iter =  220000
# training @ iter =  230000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=50, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Kindle_Store_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 46158/46158, validation error 41.963729 %
#      epoch 1, minibatch 46158/46158, test error of best model 42.152094 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# epoch 2, minibatch 46158/46158, validation error 41.963729 %
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# epoch 3, minibatch 46158/46158, validation error 41.963729 %
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# epoch 4, minibatch 46158/46158, validation error 41.963729 %
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=70, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Movies_and_TV_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 47386/47386, validation error 39.989147 %
#      epoch 1, minibatch 47386/47386, test error of best model 40.129051 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# epoch 2, minibatch 47386/47386, validation error 39.989147 %
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# epoch 3, minibatch 47386/47386, validation error 39.989147 %
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# epoch 4, minibatch 47386/47386, validation error 39.989147 %
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=10, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Musical_Instruments_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# epoch 1, minibatch 36012/36012, validation error 37.913022 %
#      epoch 1, minibatch 36012/36012, test error of best model 38.022593 %
# training @ iter =  40000
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# epoch 2, minibatch 36012/36012, validation error 37.913022 %
# training @ iter =  80000
# training @ iter =  90000
# training @ iter =  100000
# epoch 3, minibatch 36012/36012, validation error 37.913022 %
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# epoch 4, minibatch 36012/36012, validation error 37.913022 %
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# epoch 5, minibatch 36012/36012, validation error 37.913022 %
# training @ iter =  190000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=20, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Office_Products_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 44754/44754, validation error 82.225463 %
#      epoch 1, minibatch 44754/44754, test error of best model 82.098785 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# epoch 2, minibatch 44754/44754, validation error 82.225463 %
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# epoch 3, minibatch 44754/44754, validation error 82.210378 %
#      epoch 3, minibatch 44754/44754, test error of best model 82.085512 %
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# epoch 4, minibatch 44754/44754, validation error 47.996782 %
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=15, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Patio_Lawn_and_Garden_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 47687/47687, validation error 82.738140 %
#      epoch 1, minibatch 47687/47687, test error of best model 82.400725 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# epoch 2, minibatch 47687/47687, validation error 82.738140 %
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# epoch 3, minibatch 47687/47687, validation error 82.738140 %
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# epoch 4, minibatch 47687/47687, validation error 43.340883 %
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=20, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Pet_Supplies_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 44471/44471, validation error 39.880591 %
#      epoch 1, minibatch 44471/44471, test error of best model 39.691573 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# epoch 2, minibatch 44471/44471, validation error 39.880591 %
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# epoch 3, minibatch 44471/44471, validation error 39.880591 %
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# epoch 4, minibatch 44471/44471, validation error 39.880591 %
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=50, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Sports_and_Outdoors_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# epoch 1, minibatch 47069/47069, validation error 41.052974 %
#      epoch 1, minibatch 47069/47069, test error of best model 40.949824 %
# training @ iter =  50000
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# epoch 2, minibatch 47069/47069, validation error 41.052974 %
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# epoch 3, minibatch 47069/47069, validation error 41.052974 %
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# epoch 4, minibatch 47069/47069, validation error 41.052974 %
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=20, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Tools_and_Home_Improvement_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# training @ iter =  50000
# training @ iter =  60000
# epoch 1, minibatch 69337/69337, validation error 40.474429 %
#      epoch 1, minibatch 69337/69337, test error of best model 40.572430 %
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# training @ iter =  100000
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# epoch 2, minibatch 69337/69337, validation error 40.474429 %
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# epoch 3, minibatch 69337/69337, validation error 40.474429 %
# training @ iter =  210000
# training @ iter =  220000
# training @ iter =  230000
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=30, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Toys_and_Games_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# training @ iter =  50000
# epoch 1, minibatch 54066/54066, validation error 40.424505 %
#      epoch 1, minibatch 54066/54066, test error of best model 40.421938 %
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# training @ iter =  100000
# epoch 2, minibatch 54066/54066, validation error 40.424505 %
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# training @ iter =  150000
# training @ iter =  160000
# epoch 3, minibatch 54066/54066, validation error 40.424505 %
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# training @ iter =  210000
# epoch 4, minibatch 54066/54066, validation error 40.424505 %
# ...

# %%
from big_data import test_mlp
test_mlp(batch_size=15, n_epochs=10, n_hidden=[50,100],
                dataset='amazon_rating_Video_Games_new.csv',
                is_separate=True,
                lr=0.1, L1_reg=0.01, L2_reg=0.1)
# Out:
# ... loading data
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  10000
# training @ iter =  20000
# training @ iter =  30000
# training @ iter =  40000
# training @ iter =  50000
# epoch 1, minibatch 50331/50331, validation error 46.615403 %
#      epoch 1, minibatch 50331/50331, test error of best model 46.442076 %
# training @ iter =  60000
# training @ iter =  70000
# training @ iter =  80000
# training @ iter =  90000
# training @ iter =  100000
# epoch 2, minibatch 50331/50331, validation error 46.615403 %
# training @ iter =  110000
# training @ iter =  120000
# training @ iter =  130000
# training @ iter =  140000
# training @ iter =  150000
# epoch 3, minibatch 50331/50331, validation error 46.615403 %
# training @ iter =  160000
# training @ iter =  170000
# training @ iter =  180000
# training @ iter =  190000
# training @ iter =  200000
# epoch 4, minibatch 50331/50331, validation error 46.615403 %
# training @ iter =  210000
# ...
